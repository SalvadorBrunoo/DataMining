# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dataset/soybean.csv', sep=';')
df.head()
# Out:
#    Unnamed: 0     date plant-stand   precip  temp hail         crop-hist  \
# 0           0  october      normal  gt-norm  norm  yes       same-lst-yr
# 1           1   august      normal  gt-norm  norm  yes  same-lst-two-yrs
# 2           2     july      normal  gt-norm  norm  yes       same-lst-yr
# 3           3     july      normal  gt-norm  norm  yes       same-lst-yr
# 4           4  october      normal  gt-norm  norm  yes  same-lst-two-yrs
#
#   area-damaged    severity   seed-tmt  ... sclerotia fruit-pods fruit  seed  \
# 0    low-areas  pot-severe       none  ...    absent       norm   dna  norm
# 1    scattered      severe  fungicide  ...    absent       norm   dna  norm
# 2    scattered      severe  fungicide  ...    absent       norm   dna  norm
# 3    scattered      severe       none  ...    absent       norm   dna  norm
# 4    scattered  pot-severe       none  ...    absent       norm   dna  norm
#
# ...
